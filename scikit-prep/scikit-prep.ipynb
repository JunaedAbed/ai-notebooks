# %% [markdown]
# <a href="https://colab.research.google.com/github/JunaedAbed/ai-notebooks/blob/master/scikit-prep/scikit-prep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %%
df = pd.read_csv('/content/sample_data/drawndata1.csv')

# %%
df.head(3)
# Out:
#             x           y  z
# 0   58.080365  225.699042  a
# 1  238.867357  247.456645  a
# 2  156.218212  286.588782  a

# %%
X = df[['x', 'y']].values
y = df['z'] == 'a'

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)
